# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pak=pd.read_csv("Pakistan_COVID19.csv")
pak1=pd.DataFrame(pak)

# %%
pak1
# Out:
#         Province  New_Cases  Recoveries  Deaths  Vaccinations  Hospitalized  \
# 0         Punjab        138         104       6         14226            83
# 1          Sindh        206         188       2         15104            86
# 2            KPK        277         234       6         16362            28
# 3    Balochistan        371         368       4         19607            60
# 4      Islamabad        243         225       6          9466            89
# ..           ...        ...         ...     ...           ...           ...
# 495       Punjab        477         458       2          4026            16
# 496        Sindh        131          81       6          5042            91
# 497          KPK        465         415       7          2687            56
# 498  Balochistan        100          84       8          5504            14
# 499    Islamabad        213         165      10          6993            50
#
#      Tests_Conducted
# 0               7342
# ...

# %%
pak.columns
# Out:
# Index(['Province', 'New_Cases', 'Recoveries', 'Deaths', 'Vaccinations',
#        'Hospitalized', 'Tests_Conducted'],
#       dtype='object')

# %%
pak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Province         500 non-null    object
#  1   New_Cases        500 non-null    int64
#  2   Recoveries       500 non-null    int64
#  3   Deaths           500 non-null    int64
#  4   Vaccinations     500 non-null    int64
#  5   Hospitalized     500 non-null    int64
#  6   Tests_Conducted  500 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 27.5+ KB

# %%
pak.tail(5)
# Out:
#         Province  New_Cases  Recoveries  Deaths  Vaccinations  Hospitalized  \
# 495       Punjab        477         458       2          4026            16
# 496        Sindh        131          81       6          5042            91
# 497          KPK        465         415       7          2687            56
# 498  Balochistan        100          84       8          5504            14
# 499    Islamabad        213         165      10          6993            50
#
#      Tests_Conducted
# 495            14958
# 496            11550
# 497            10936
# 498            11490
# 499             6074

# %%
pak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Province         500 non-null    object
#  1   New_Cases        500 non-null    int64
#  2   Recoveries       500 non-null    int64
#  3   Deaths           500 non-null    int64
#  4   Vaccinations     500 non-null    int64
#  5   Hospitalized     500 non-null    int64
#  6   Tests_Conducted  500 non-null    int64
#  7   Death_Rate       500 non-null    float64
#  8   Recovery_Rate    500 non-null    float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 35.3+ KB

# %%
pak['Province']
# Out:
# 0           Punjab
# 1            Sindh
# 2              KPK
# 3      Balochistan
# 4        Islamabad
#           ...
# 495         Punjab
# 496          Sindh
# 497            KPK
# 498    Balochistan
# 499      Islamabad
# Name: Province, Length: 500, dtype: object

# %%
pak['Hospitalized']
# Out:
# 0      83
# 1      86
# 2      28
# 3      60
# 4      89
#        ..
# 495    16
# 496    91
# 497    56
# 498    14
# 499    50
# Name: Hospitalized, Length: 500, dtype: int64

# %%
pak[pak['New_Cases']>200]
# Out:
#         Province  New_Cases  Recoveries  Deaths  Vaccinations  Hospitalized  \
# 1          Sindh        206         188       2         15104            86
# 2            KPK        277         234       6         16362            28
# 3    Balochistan        371         368       4         19607            60
# 4      Islamabad        243         225       6          9466            89
# 6          Sindh        248         205       1         16985            68
# ..           ...        ...         ...     ...           ...           ...
# 489    Islamabad        419         414       2         11816            33
# 491        Sindh        432         387       9         16304            24
# 495       Punjab        477         458       2          4026            16
# 497          KPK        465         415       7          2687            56
# 499    Islamabad        213         165      10          6993            50
#
#      Tests_Conducted
# 1               2470
# ...

# %%
pak.groupby('Province')['New_Cases'].apply('sum')
# Out:
# Province
# Balochistan    26915
# Islamabad      26950
# KPK            24667
# Punjab         25030
# Sindh          27174
# Name: New_Cases, dtype: int64

# %%
len(pak.columns)
# Out:
# 7

# %%
len(pak.index)
# Out:
# 500

# %%
pak['Death_Rate']=pak['Deaths']/pak['New_Cases']
pak['Recovery_Rate']=pak['Recoveries']/pak['New_Cases']
pak.head(7)
# Out:
#       Province  New_Cases  Recoveries  Deaths  Vaccinations  Hospitalized  \
# 0       Punjab        138         104       6         14226            83
# 1        Sindh        206         188       2         15104            86
# 2          KPK        277         234       6         16362            28
# 3  Balochistan        371         368       4         19607            60
# 4    Islamabad        243         225       6          9466            89
# 5       Punjab        145         140       9         12450            99
# 6        Sindh        248         205       1         16985            68
#
#    Tests_Conducted  Death_Rate  Recovery_Rate
# 0             7342    0.043478       0.753623
# 1             2470    0.009709       0.912621
# 2            26118    0.021661       0.844765
# 3            28117    0.010782       0.991914
# 4            18861    0.024691       0.925926
# 5             7291    0.062069       0.965517
# 6            17987    0.004032       0.826613

# %%
pak.groupby('Province')['Vaccinations'].apply('max')
# Out:
# Province
# Balochistan    19896
# Islamabad      19936
# KPK            19771
# Punjab         19916
# Sindh          19819
# Name: Vaccinations, dtype: int64

# %%
pak['Vaccinations'].max()
# Out:
# np.int64(19936)

# %%
pak.groupby('Province')['Deaths'].apply('max')
# Out:
# Province
# Balochistan    10
# Islamabad      10
# KPK            10
# Punjab         10
# Sindh          10
# Name: Deaths, dtype: int64

# %%
x=np.linspace(0,10,20)

# %%
y=x**2

# %%
x,y
# Out:
# (array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#          2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#          5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#          7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ]),
#  array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#           4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#          17.72853186,  22.43767313,  27.70083102,  33.51800554,
#          39.88919668,  46.81440443,  54.29362881,  62.32686981,
#          70.91412742,  80.05540166,  89.75069252, 100.        ]))

# %%
fig, ax = plt.subplots()
bottom = np.zeros(3)


ax.plot(pak["Vaccinations"], pak["New_Cases"])



ax.set_title('Number of penguins by sex')
ax.legend("new","old")

plt.show()
plt.savefig("Pakistani absurd photo")
# Out:
# /tmp/ipykernel_15628/1181727168.py:10: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   ax.legend("new","old")
