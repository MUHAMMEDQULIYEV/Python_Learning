# %%
import numpy as np
from numpy.random import randn

# %%
import pandas as pd

# %%
s="mahammad"
labels=list(s)

# %%
labels
# Out:
# ['m', 'a', 'h', 'a', 'm', 'm', 'a', 'd']

# %%
my_data=[19,47,4,7]
arr=np.arange(4,47,7)

# %%
arr
# Out:
# array([ 4, 11, 18, 25, 32, 39, 46])

# %%
di={'a':5,'b':47}

# %%
di
# Out:
# {'a': 5, 'b': 47}

# %%
pd.Series(data=my_data)
# Out:
# 0    19
# 1    47
# 2     4
# 3     7
# dtype: int64

# %%
pd.Series(di)
# Out:
# a     5
# b    47
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3855426915.py in <cell line: 0>()
# ----> 1 pd.Series(arr,index=labels)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     573             index = default_index(len(data))
#     574         elif is_list_like(data):
# --> 575             com.require_length_match(data, index)
#     576
#     577         # create/copy the manager
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (7) does not match length of index (8)

# %%
sr1=pd.Series(['m', 'a', 'h', 'a', 'm', 'm', 'a', 'd'],["germany","usa","azerbaijan","turkey","hungary","portugal","uzbekistan","russia"])

# %%
sr1
# Out:
# germany       m
# usa           a
# azerbaijan    h
# turkey        a
# hungary       m
# portugal      m
# uzbekistan    a
# russia        d
# dtype: object

# %%
sr1['russia']
# Out:
# 'd'

# %%
np.random.seed(4)

# %%
df=pd.DataFrame(data=np.random.randn(6,5),index=np.arange(6),columns=['x','y','z','h','j',])

# %%
df
# Out:
#           x         y         z         h         j
# 0 -0.508380  1.005982  1.531791 -0.593602  0.764106
# 1 -0.329567 -0.171115  0.184285 -0.401177  0.895104
# 2 -1.495852 -0.695397 -0.119411 -1.044824  0.360638
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073
# 4  2.203564  1.077634  1.617241  0.067972  2.115736
# 5 -0.241259 -0.252198 -1.282083  0.222252  1.053600

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['x'])
# Out:
# pandas.core.series.Series

# %%
df.x
# Out:
# 0   -0.508380
# 1   -0.329567
# 2   -1.495852
# 3   -1.514904
# 4    2.203564
# 5   -0.241259
# Name: x, dtype: float64

# %%
df.y
# Out:
# 0    1.005982
# 1   -0.171115
# 2   -0.695397
# 3    0.055178
# 4    1.077634
# 5   -0.252198
# Name: y, dtype: float64

# %%
df[['y','x']]
# Out:
#           y         x
# 0  1.005982 -0.508380
# 1 -0.171115 -0.329567
# 2 -0.695397 -1.495852
# 3  0.055178 -1.514904
# 4  1.077634  2.203564
# 5 -0.252198 -0.241259

# %%
df['f']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3331641397.py in <cell line: 0>()
# ----> 1 df['f']
#
# ...

# %%
df['k']=df['x']+df['y']

# %%
df
# Out:
#           x         y         z         h         j         k
# 0 -0.508380  1.005982  1.531791 -0.593602  0.764106  0.497602
# 1 -0.329567 -0.171115  0.184285 -0.401177  0.895104 -0.500682
# 2 -1.495852 -0.695397 -0.119411 -1.044824  0.360638 -2.191249
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073 -1.459727
# 4  2.203564  1.077634  1.617241  0.067972  2.115736  3.281198
# 5 -0.241259 -0.252198 -1.282083  0.222252  1.053600 -0.493456

# %%
df.drop('h',axis=1)
# Out:
#           x         y         z         j         k
# 0 -0.508380  1.005982  1.531791  0.764106  0.497602
# 1 -0.329567 -0.171115  0.184285  0.895104 -0.500682
# 2 -1.495852 -0.695397 -0.119411  0.360638 -2.191249
# 3 -1.514904  0.055178 -1.440265  0.508073 -1.459727
# 4  2.203564  1.077634  1.617241  2.115736  3.281198
# 5 -0.241259 -0.252198 -1.282083  1.053600 -0.493456

# %%
df
# Out:
#           x         y         z         h         j         k
# 0 -0.508380  1.005982  1.531791 -0.593602  0.764106  0.497602
# 1 -0.329567 -0.171115  0.184285 -0.401177  0.895104 -0.500682
# 2 -1.495852 -0.695397 -0.119411 -1.044824  0.360638 -2.191249
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073 -1.459727
# 4  2.203564  1.077634  1.617241  0.067972  2.115736  3.281198
# 5 -0.241259 -0.252198 -1.282083  0.222252  1.053600 -0.493456

# %%
df.drop('k',axis=1,inplace=True)

# %%
df
# Out:
#           x         y         z         h         j
# 0 -0.508380  1.005982  1.531791 -0.593602  0.764106
# 1 -0.329567 -0.171115  0.184285 -0.401177  0.895104
# 2 -1.495852 -0.695397 -0.119411 -1.044824  0.360638
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073
# 4  2.203564  1.077634  1.617241  0.067972  2.115736
# 5 -0.241259 -0.252198 -1.282083  0.222252  1.053600

# %%
df.drop(5,axis=0)
# Out:
#           x         y         z         h         j
# 0 -0.508380  1.005982  1.531791 -0.593602  0.764106
# 1 -0.329567 -0.171115  0.184285 -0.401177  0.895104
# 2 -1.495852 -0.695397 -0.119411 -1.044824  0.360638
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073
# 4  2.203564  1.077634  1.617241  0.067972  2.115736

# %%
df.shape
# Out:
# (6, 5)

# %%
df
# Out:
#           x         y         z         h         j
# 0 -0.508380  1.005982  1.531791 -0.593602  0.764106
# 1 -0.329567 -0.171115  0.184285 -0.401177  0.895104
# 2 -1.495852 -0.695397 -0.119411 -1.044824  0.360638
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073
# 4  2.203564  1.077634  1.617241  0.067972  2.115736
# 5 -0.241259 -0.252198 -1.282083  0.222252  1.053600

# %%
df.loc[[3]]
# Out:
#           x         y         z         h         j
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073

# %%
df.iloc[[3]]
# Out:
#           x         y         z         h         j
# 3 -1.514904  0.055178 -1.440265 -0.145247  0.508073

# %%
df.loc[[2,4],['y','z']]
# Out:
#           y         z
# 2 -0.695397 -0.119411
# 4  1.077634  1.617241
