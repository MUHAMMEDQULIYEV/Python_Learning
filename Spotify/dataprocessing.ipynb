# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

music=pd.read_csv("track_data_final.csv")

# %%
music=pd.DataFrame(data=music)

# %%
music
# Out:
#                     track_id                              track_name  \
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 0               57                61             213173     False
# ...

# %%
music['artist_popularity']
# Out:
# 0        80.0
# 1        69.0
# 2       100.0
# 3        90.0
# 4        90.0
#         ...
# 8773     66.0
# 8774      8.0
# 8775     94.0
# 8776     68.0
# 8777     88.0
# Name: artist_popularity, Length: 8778, dtype: float64

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8778 entries, 0 to 8777
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8778 non-null   object
#  1   track_name          8776 non-null   object
#  2   track_number        8778 non-null   int64
#  3   track_popularity    8778 non-null   int64
#  4   track_duration_ms   8778 non-null   int64
#  5   explicit            8778 non-null   bool
#  6   artist_name         8774 non-null   object
#  7   artist_popularity   8774 non-null   float64
#  8   artist_followers    8774 non-null   float64
#  9   artist_genres       8774 non-null   object
#  10  album_id            8778 non-null   object
#  11  album_name          8776 non-null   object
#  12  album_release_date  8778 non-null   object
#  13  album_total_tracks  8778 non-null   int64
#  14  album_type          8778 non-null   object
# ...

# %%
music.describe
# Out:
# <bound method NDFrame.describe of                     track_id                              track_name  \
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# ...

# %%
sns.pairplot(data=music)

# %%
music[music['track_duration_ms']>4]
# Out:
#                     track_id                              track_name  \
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 0               57                61             213173     False
# ...

# %%
music.groupby('album_type').count()
# Out:
#              track_id  track_name  track_number  track_popularity  \
# album_type
# album            6022        6022          6022              6022
# compilation       508         508           508               508
# single           2248        2246          2248              2248
#
#              track_duration_ms  explicit  artist_name  artist_popularity  \
# album_type
# album                     6022      6022         6020               6020
# compilation                508       508          508                508
# single                    2248      2248         2246               2246
#
#              artist_followers  artist_genres  album_id  album_name  \
# album_type
# album                    6020           6020      6022        6022
# compilation               508            508       508         508
# single                   2246           2246      2248        2246
#
#              album_release_date  album_total_tracks
# album_type
# ...

# %%
sns.displot(data=music.groupby('album_type').count())

# %%
sns.pairplot(data=music.groupby('album_type').count())

# %%
music.loc[3:5,"track_id":"track_popularity"]
# Out:
#                  track_id                 track_name  track_number  \
# 3  7bcy34fBT2ap1L4bfPsl9q  I Didn't Change My Number             2
# 4  0GLfodYacy3BJE7AI3A8en                   Man Down             7
# 5  7H0ya83CMmgFcOhw0UB6ow                 Space Song             3
#
#    track_popularity
# 3                72
# 4                57
# 5                77

# %%
music.isna()
# Out:
#       track_id  track_name  track_number  track_popularity  track_duration_ms  \
# 0        False       False         False             False              False
# 1        False       False         False             False              False
# 2        False       False         False             False              False
# 3        False       False         False             False              False
# 4        False       False         False             False              False
# ...        ...         ...           ...               ...                ...
# 8773     False       False         False             False              False
# 8774     False       False         False             False              False
# 8775     False       False         False             False              False
# 8776     False       False         False             False              False
# 8777     False       False         False             False              False
#
# ...

# %%
music.isna().any(axis=0)
# Out:
# track_id              False
# track_name             True
# track_number          False
# track_popularity      False
# track_duration_ms     False
# explicit              False
# artist_name            True
# artist_popularity      True
# artist_followers       True
# artist_genres          True
# album_id              False
# album_name             True
# album_release_date    False
# album_total_tracks    False
# album_type            False
# dtype: bool

# %%
music[music['artist_name'].isna()]
# Out:
#                     track_id            track_name  track_number  \
# 436   3QhfFRPkhPCR1RMJWV1gde                 Radio             8
# 1396  2NbsBSshscKIPRG3kwBbfo   Never Felt So Alone             1
# 3885  5EhZC8GFOVXrpiUW22jncE        Urban Twilight             4
# 3886  0fM9dEhUFV4MHDuJgrcfOv  How You Get The Girl            10
#
#       track_popularity  track_duration_ms  explicit artist_name  \
# 436                 65             214586      True         NaN
# 1396                68             160166     False         NaN
# 3885                30             255634     False         NaN
# 3886                59             247533     False         NaN
#
#       artist_popularity  artist_followers artist_genres  \
# 436                 NaN               NaN           NaN
# 1396                NaN               NaN           NaN
# 3885                NaN               NaN           NaN
# 3886                NaN               NaN           NaN
#
# ...

# %%
sns.pairplot(data=music[music['artist_name'].isna()])

# %%
music.groupby("artist_name")['track_duration_ms'].apply('max')
# Out:
# artist_name
# $uicideboy$         203897
# 'Ery Noice           70191
# (((())))            148468
# *NSYNC              200400
# -                   104007
#                      ...
# 攬佬SKAI ISYOURGOD    151111
# 時瀬高等学校箏曲部           478813
# 桑原まこ                125333
# 梶浦 由記               113933
# 藤澤慶昌                152000
# Name: track_duration_ms, Length: 2548, dtype: int64

# %%
# Example: plot track duration vs popularity
sns.jointplot(data=music, x='track_popularity', y='track_duration_ms')

# %%
music.corr(numeric_only=True)
# Out:
#                     track_number  track_popularity  track_duration_ms  \
# track_number            1.000000         -0.024465           0.070455
# track_popularity       -0.024465          1.000000           0.107116
# track_duration_ms       0.070455          0.107116           1.000000
# explicit               -0.009311          0.126507           0.009494
# artist_popularity       0.188944          0.455739           0.212325
# artist_followers        0.221637          0.226570           0.175630
# album_total_tracks      0.518550         -0.047275           0.067941
#
#                     explicit  artist_popularity  artist_followers  \
# track_number       -0.009311           0.188944          0.221637
# track_popularity    0.126507           0.455739          0.226570
# track_duration_ms   0.009494           0.212325          0.175630
# explicit            1.000000           0.172190          0.102331
# artist_popularity   0.172190           1.000000          0.637667
# ...

# %%
sns.pairplot(data=music.corr(numeric_only=True))

# %%
sns.lmplot(data=music)
