# %%
import pandas as pd
import numpy as np
from plotly import __version__
import plotly.express as px
print(__version__)
# Out:
# 6.5.0

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>

# %%
cf.go_offline()
cf.set_config_file(offline=True, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>

# %%
#Data
df=np.random.randn(100,4)

# %%
df
# Out:
# array([[-8.57976263e-01,  1.71394834e+00,  5.09230387e-01,
#         -1.04043981e-01],
#        [-1.45785542e+00, -4.73379567e-01, -6.31612089e-01,
#          4.38527609e-01],
#        [-1.54314050e-01,  2.26325625e-01, -6.45747260e-01,
#         -2.03197522e-01],
#        [-1.17330340e+00, -5.15513472e-01, -6.04833684e-01,
#         -1.46304172e+00],
#        [ 5.35820826e-01,  1.62616642e+00, -1.80904507e+00,
#         -1.32717468e+00],
#        [ 2.00819460e+00,  8.17314851e-01,  7.97859105e-01,
#         -1.12639612e+00],
#        [-2.98135634e-01,  7.42965553e-01,  1.52608669e-01,
#          3.92653331e-01],
#        [ 1.55877777e+00, -1.92460430e+00,  3.99489250e-01,
#          1.37219029e+00],
#        [ 2.95917707e-01, -1.60836419e-01, -9.10140209e-01,
#         -1.22333882e+00],
#        [ 4.00647707e-01,  1.31661865e+00, -1.26700029e+00,
#         -6.95778987e-02],
#        [ 9.82891943e-01, -1.50735124e-01, -7.03180127e-01,
#          1.59602184e-01],
#        [-3.85538911e-01, -9.77025151e-01, -1.80707073e-01,
#          2.86920672e-01],
#        [ 1.47776253e+00,  1.16274766e-01,  1.74192049e+00,
#          4.39588906e-01],
#        [-5.55277855e-01, -7.74757107e-01,  5.09401602e-02,
#         -2.59594673e-01],
#        [ 1.17458888e+00,  1.09289556e+00,  1.04780696e-02,
#         -1.43031180e+00],
#        [ 6.40676521e-03, -1.04063209e+00, -5.05123997e-01,
#          2.16434522e+00],
#        [ 1.03235630e-01, -3.45961182e-02, -2.26985884e-01,
#         -6.20900158e-01],
#        [ 8.17748749e-01,  2.35440486e+00,  6.50957221e-01,
#         -1.18640683e+00],
#        [ 8.93039989e-01,  1.14607166e+00, -6.06021491e-02,
#         -2.65700747e+00],
#        [-1.46669719e+00, -2.06861141e-01, -2.31614266e-01,
#          8.09873891e-01],
#        [-1.06736985e+00,  3.89254530e-01,  7.49956294e-01,
#          1.75230222e-01],
#        [ 3.68444873e-01,  2.49045676e-01,  3.56662278e-01,
#         -7.78419974e-01],
#        [ 3.68235518e-01,  7.72731820e-01, -1.56433224e-02,
#          7.73254108e-01],
#        [-1.93033029e-01,  1.00402938e+00,  7.21922588e-01,
#          8.70896334e-03],
#        [-6.03056366e-01, -8.43350333e-01, -5.12443607e-01,
#         -1.66326089e+00],
#        [-5.27795087e-01,  1.15961709e+00,  1.05727112e+00,
#          6.18878443e-02],
#        [ 5.07242166e-01, -9.46898644e-01, -1.30381106e+00,
#          8.23999618e-01],
#        [-5.09984051e-01,  1.76979343e+00, -9.09557193e-02,
#         -1.23980035e+00],
#        [-1.18821176e+00,  4.71180348e-01,  3.96414022e-01,
#         -2.85580667e-01],
#        [-2.50490725e-01,  3.47370187e-01, -1.22655920e+00,
#         -5.02707204e-01],
#        [ 3.74371248e-01, -3.18155281e-01,  4.65986116e-01,
#         -3.99033683e-01],
#        [ 6.51949012e-01,  1.13639900e+00,  5.50095393e-01,
#         -1.41771384e-01],
#        [ 1.51671700e+00,  4.72442469e-01,  2.39854098e+00,
#         -3.80158165e-01],
#        [-7.12812385e-01, -9.23549242e-01, -8.61487072e-01,
#          3.28254120e-01],
#        [-6.61046213e-01,  3.87794239e-01,  5.42480886e-01,
#          1.09583541e+00],
#        [ 1.65848766e-01, -1.49802908e+00,  8.69869470e-01,
#          6.41519138e-01],
#        [ 1.60358665e+00,  1.01987215e+00,  6.06862146e-01,
#         -1.01839374e+00],
#        [-3.03911730e-01,  2.83858433e-01, -7.30450776e-01,
#          6.85934756e-01],
#        [-1.07290402e+00,  6.80018183e-02,  1.25730733e+00,
#          2.93089297e-02],
#        [ 2.54765471e+00, -1.16748839e+00, -3.08796239e-01,
#          1.32030532e+00],
#        [-1.05332767e+00, -1.11337198e-01, -8.19780441e-01,
#          4.30150557e-02],
#        [-2.02461995e-01,  3.76403495e-01, -1.00909523e+00,
#         -1.52891035e-01],
#        [ 2.65822269e+00,  8.96543226e-01,  8.31200700e-01,
#         -8.82175499e-01],
#        [-8.93473252e-02, -4.96366591e-01,  2.00360214e+00,
#         -1.18452543e+00],
#        [ 1.18105199e+00, -1.53044511e+00, -9.46355731e-02,
#         -5.71507421e-01],
#        [-6.24932606e-01, -1.35710430e+00,  5.60810916e-01,
#          2.16349265e-01],
#        [ 2.38278521e-01,  5.28200869e-01, -6.35496578e-01,
#         -7.49802467e-01],
#        [ 3.15883922e-01, -1.89888768e+00,  4.49548893e-01,
#         -1.31850258e+00],
#        [ 1.48579077e+00,  5.59858950e-01,  4.96223491e-01,
#         -1.42734303e+00],
#        [-2.17104425e-01, -1.59187845e+00, -3.80748655e-01,
#          5.83217947e-01],
#        [-1.65693592e+00, -6.80564385e-01,  1.05817144e+00,
#          7.55665164e-01],
#        [ 9.65837219e-01, -1.16553562e+00, -3.04365586e-02,
#          4.88456523e-01],
#        [-7.15166174e-01, -1.77192533e-02,  4.47105891e-01,
#         -1.05796558e+00],
#        [-7.67412388e-01, -4.45943211e-01,  1.34780681e+00,
#         -8.67602866e-01],
#        [ 1.02770172e-01, -2.22265457e+00, -1.98273964e+00,
#         -1.11607567e+00],
#        [-4.22555071e-01,  1.18778663e+00, -4.27800063e-01,
#          2.78592033e-01],
#        [-1.65405012e-01, -1.94228731e-01,  1.88099375e-01,
#         -1.82961934e+00],
#        [-1.04633502e-01,  2.26840277e+00,  1.31438538e+00,
#         -1.03821715e+00],
#        [ 8.20050495e-01, -4.84956001e-01,  7.15819590e-01,
#         -1.09026861e+00],
#        [ 6.58534948e-01,  2.90698449e-02, -1.72816726e-01,
#         -2.90566557e-01],
#        [-5.42693493e-01,  3.17512322e+00,  1.44794828e-01,
#          1.59094026e+00],
#        [-1.72054900e-01,  1.74921541e-01, -1.75647228e+00,
#          1.74281067e+00],
#        [ 7.32440142e-01, -7.48923903e-01,  8.18057446e-01,
#         -1.34506744e+00],
#        [-7.49845117e-01,  7.44101981e-02, -6.15303577e-01,
#          2.60564261e-03],
#        [ 1.20443721e-01, -4.44872130e-01, -8.05856695e-01,
#         -4.22019229e-01],
#        [-2.95227705e-01, -3.59780942e-01,  1.24110177e+00,
#         -2.33499341e+00],
#        [ 1.32067175e+00, -1.01495550e+00, -1.39871216e+00,
#         -5.48984087e-02],
#        [-8.84149473e-01, -2.55719500e-01, -3.48115059e-01,
#         -5.98764938e-01],
#        [-1.19745704e-01, -4.33144339e-01,  1.11333588e+00,
#         -1.40018147e+00],
#        [-1.31606018e+00, -9.28178671e-01, -1.90677213e+00,
#         -1.08989740e+00],
#        [ 1.30924050e+00,  6.42178627e-01,  5.80162589e-01,
#         -5.96170013e-01],
#        [-1.26460849e-01, -1.52426653e+00, -4.71731113e-02,
#         -1.63047110e+00],
#        [ 1.39476042e+00, -1.10521368e+00,  2.00244111e+00,
#         -7.85561442e-01],
#        [ 9.01053869e-01,  1.17424891e+00,  3.10279901e-01,
#         -1.67417346e-01],
#        [ 2.34792657e-01,  6.58074510e-01,  7.38108081e-01,
#         -2.46970850e+00],
#        [ 6.33475413e-01, -1.44289069e+00, -3.99266930e-01,
#          1.63933352e+00],
#        [-3.18003698e-01, -2.58342323e-01,  8.21722624e-01,
#          1.26324066e+00],
#        [-6.76357022e-01, -1.65458725e+00, -1.76021489e-01,
#          5.84700263e-01],
#        [-5.35949538e-01,  2.48776150e-01,  1.75946609e-01,
#          9.77790944e-01],
#        [ 9.72939125e-01, -1.52957814e-02, -1.73946532e+00,
#          5.14651435e-01],
#        [ 1.00623687e+00, -6.81801568e-02, -1.14317978e+00,
#         -7.62966942e-01],
#        [-1.76999854e-01,  1.57640020e+00,  3.09688427e-01,
#         -1.98485037e-01],
#        [-6.32252201e-01,  2.22963898e-01,  4.94830107e-01,
#         -1.14776536e+00],
#        [ 8.04014431e-01,  1.04825841e+00,  8.51383403e-01,
#         -1.02305496e+00],
#        [ 1.07207098e+00, -1.49996087e+00,  2.02937073e+00,
#         -1.17176874e+00],
#        [ 1.57374854e+00,  7.53698583e-01, -1.10646751e-01,
#         -1.50182117e+00],
#        [ 3.00658457e-01,  2.22343920e-01,  2.03811226e-01,
#          2.65658778e-01],
#        [ 1.13284320e+00, -1.20440167e-01,  4.96667196e-01,
#         -5.20704750e-01],
#        [-3.67611277e-01,  8.33784814e-01, -1.50694373e+00,
#         -1.31904473e+00],
#        [ 2.81339812e-01,  3.90213300e-01, -7.66827686e-01,
#         -8.59595608e-01],
#        [ 7.96095765e-01,  1.99253212e-01, -1.91425226e-01,
#          1.19650312e+00],
#        [-3.65878953e-01, -2.94019552e+00,  1.19793275e+00,
#         -1.22523954e+00],
#        [-8.27783034e-01,  1.69992531e+00, -9.81074551e-01,
#          1.07622799e+00],
#        [-3.97862904e-01,  1.20539212e+00,  8.37235266e-02,
#          1.25733635e+00],
#        [ 4.26388822e-02, -1.31027866e+00, -1.61110522e+00,
#          2.19164627e-01],
#        [ 1.18127849e+00, -1.31241880e+00, -9.62428205e-01,
#          8.86220116e-01],
#        [-5.01349492e-01,  2.52330966e-01,  1.31211944e+00,
#          7.83118114e-01],
#        [ 2.27049156e-01, -1.56334341e+00,  4.92617999e-01,
#          5.27864596e-01],
#        [ 1.01911893e+00, -1.52971771e+00,  4.28114285e-01,
#          1.82497896e+00],
#        [-7.90550741e-01, -4.41425336e-01,  5.70130484e-01,
#          1.28511549e+00]])

# %%
df=pd.DataFrame(df,columns="A B C D".split())

# %%
df
# Out:
#            A         B         C         D
# 0  -0.857976  1.713948  0.509230 -0.104044
# 1  -1.457855 -0.473380 -0.631612  0.438528
# 2  -0.154314  0.226326 -0.645747 -0.203198
# 3  -1.173303 -0.515513 -0.604834 -1.463042
# 4   0.535821  1.626166 -1.809045 -1.327175
# ..       ...       ...       ...       ...
# 95  1.181278 -1.312419 -0.962428  0.886220
# 96 -0.501349  0.252331  1.312119  0.783118
# 97  0.227049 -1.563343  0.492618  0.527865
# 98  1.019119 -1.529718  0.428114  1.824979
# 99 -0.790551 -0.441425  0.570130  1.285115
#
# [100 rows x 4 columns]

# %%
df2=pd.DataFrame({'Category':['A' ,'B', 'C', 'D'],"Values":[32,21,45,13]})
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      21
# 2        C      45
# 3        D      13

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
fig=px.scatter(df,x='A',y='B',template=None)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 fig=px.scatter(df,x='A',y='B',template=None)
#       2 fig.show()
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/express/_chart_types.py:69, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, subtitle, template, width, height)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/express/_core.py:2770, in make_figure(args, constructor, trace_patch, layout_patch)
#    2768 fig.update_layout(layout_patch)
#    2769 if "template" in args and args["template"] is not None:
# -> 2770     fig.update_layout(template=args["template"], overwrite=True)
#    2771 for f in frame_list:
#    2772     f["name"] = str(f["name"])
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/graph_objs/_figure.py:218, in update_layout(self, dict1, overwrite, **kwargs)
#       5 def __init__(
#       6     self, data=None, layout=None, frames=None, skip_invalid=False, **kwargs
#       7 ):
#       8     """
#       9     Create a new :class:Figure instance
#      10
#      11     Parameters
#      12     ----------
#      13     data
#      14         The 'data' property is a tuple of trace instances
#      15         that may be specified as:
#      16           - A list or tuple of trace instances
#      17             (e.g. [Scatter(...), Bar(...)])
#      18           - A single trace instance
#      19             (e.g. Scatter(...), Bar(...), etc.)
#      20           - A list or tuple of dicts of string/value properties where:
#      21             - The 'type' property specifies the trace type
#      22                 One of: ['area', 'bar', 'barpolar', 'box',
#      23                          'candlestick', 'carpet', 'choropleth',
#      24                          'choroplethmapbox', 'cone', 'contour',
#      25                          'contourcarpet', 'densitymapbox', 'funnel',
#      26                          'funnelarea', 'heatmap', 'heatmapgl',
#      27                          'histogram', 'histogram2d',
#      28                          'histogram2dcontour', 'image', 'indicator',
#      29                          'isosurface', 'mesh3d', 'ohlc', 'parcats',
#      30                          'parcoords', 'pie', 'pointcloud', 'sankey',
#      31                          'scatter', 'scatter3d', 'scattercarpet',
#      32                          'scattergeo', 'scattergl', 'scattermapbox',
#      33                          'scatterpolar', 'scatterpolargl',
#      34                          'scatterternary', 'splom', 'streamtube',
#      35                          'sunburst', 'surface', 'table', 'treemap',
#      36                          'violin', 'volume', 'waterfall']
#      37
#      38             - All remaining properties are passed to the constructor of
#      39               the specified trace type
#      40
#      41             (e.g. [{'type': 'scatter', ...}, {'type': 'bar, ...}])
#      42
#      43     layout
#      44         The 'layout' property is an instance of Layout
#      45         that may be specified as:
#      46           - An instance of :class:`plotly.graph_objs.Layout`
#      47           - A dict of string/value properties that will be passed
#      48             to the Layout constructor
#      49
#      50             Supported dict properties:
#      51
#      52                 activeshape
#      53                     :class:`plotly.graph_objects.layout.Activeshape
#      54                     ` instance or dict with compatible properties
#      55                 angularaxis
#      56                     :class:`plotly.graph_objects.layout.AngularAxis
#      57                     ` instance or dict with compatible properties
#      58                 annotations
#      59                     A tuple of
#      60                     :class:`plotly.graph_objects.layout.Annotation`
#      61                     instances or dicts with compatible properties
#      62                 annotationdefaults
#      63                     When used in a template (as
#      64                     layout.template.layout.annotationdefaults),
#      65                     sets the default property values to use for
#      66                     elements of layout.annotations
#      67                 autosize
#      68                     Determines whether or not a layout width or
#      69                     height that has been left undefined by the user
#      70                     is initialized on each relayout. Note that,
#      71                     regardless of this attribute, an undefined
#      72                     layout width or height is always initialized on
#      73                     the first call to plot.
#      74                 autotypenumbers
#      75                     Using "strict" a numeric string in trace data
#      76                     is not converted to a number. Using *convert
#      77                     types* a numeric string in trace data may be
#      78                     treated as a number during automatic axis
#      79                     `type` detection. This is the default value;
#      80                     however it could be overridden for individual
#      81                     axes.
#      82                 bargap
#      83                     Sets the gap (in plot fraction) between bars of
#      84                     adjacent location coordinates.
#      85                 bargroupgap
#      86                     Sets the gap (in plot fraction) between bars of
#      87                     the same location coordinate.
#      88                 barmode
#      89                     Determines how bars at the same location
#      90                     coordinate are displayed on the graph. With
#      91                     "stack", the bars are stacked on top of one
#      92                     another With "relative", the bars are stacked
#      93                     on top of one another, with negative values
#      94                     below the axis, positive values above With
#      95                     "group", the bars are plotted next to one
#      96                     another centered around the shared location.
#      97                     With "overlay", the bars are plotted over one
#      98                     another, you might need to an "opacity" to see
#      99                     multiple bars.
#     100                 barnorm
#     101                     Sets the normalization for bar traces on the
#     102                     graph. With "fraction", the value of each bar
#     103                     is divided by the sum of all values at that
#     104                     location coordinate. "percent" is the same but
#     105                     multiplied by 100 to show percentages.
#     106                 boxgap
#     107                     Sets the gap (in plot fraction) between boxes
#     108                     of adjacent location coordinates. Has no effect
#     109                     on traces that have "width" set.
#     110                 boxgroupgap
#     111                     Sets the gap (in plot fraction) between boxes
#     112                     of the same location coordinate. Has no effect
#     113                     on traces that have "width" set.
#     114                 boxmode
#     115                     Determines how boxes at the same location
#     116                     coordinate are displayed on the graph. If
#     117                     "group", the boxes are plotted next to one
#     118                     another centered around the shared location. If
#     119                     "overlay", the boxes are plotted over one
#     120                     another, you might need to set "opacity" to see
#     121                     them multiple boxes. Has no effect on traces
#     122                     that have "width" set.
#     123                 calendar
#     124                     Sets the default calendar system to use for
#     125                     interpreting and displaying dates throughout
#     126                     the plot.
#     127                 clickmode
#     128                     Determines the mode of single click
#     129                     interactions. "event" is the default value and
#     130                     emits the `plotly_click` event. In addition
#     131                     this mode emits the `plotly_selected` event in
#     132                     drag modes "lasso" and "select", but with no
#     133                     event data attached (kept for compatibility
#     134                     reasons). The "select" flag enables selecting
#     135                     single data points via click. This mode also
#     136                     supports persistent selections, meaning that
#     137                     pressing Shift while clicking, adds to /
#     138                     subtracts from an existing selection. "select"
#     139                     with `hovermode`: "x" can be confusing,
#     140                     consider explicitly setting `hovermode`:
#     141                     "closest" when using this feature. Selection
#     142                     events are sent accordingly as long as "event"
#     143                     flag is set as well. When the "event" flag is
#     144                     missing, `plotly_click` and `plotly_selected`
#     145                     events are not fired.
#     146                 coloraxis
#     147                     :class:`plotly.graph_objects.layout.Coloraxis`
#     148                     instance or dict with compatible properties
#     149                 colorscale
#     150                     :class:`plotly.graph_objects.layout.Colorscale`
#     151                     instance or dict with compatible properties
#     152                 colorway
#     153                     Sets the default trace colors.
#     154                 computed
#     155                     Placeholder for exporting automargin-impacting
#     156                     values namely `margin.t`, `margin.b`,
#     157                     `margin.l` and `margin.r` in "full-json" mode.
#     158                 datarevision
#     159                     If provided, a changed value tells
#     160                     `Plotly.react` that one or more data arrays has
#     161                     changed. This way you can modify arrays in-
#     162                     place rather than making a complete new copy
#     163                     for an incremental change. If NOT provided,
#     164                     `Plotly.react` assumes that data arrays are
#     165                     being treated as immutable, thus any data array
#     166                     with a different identity from its predecessor
#     167                     contains new data.
#     168                 direction
#     169                     Legacy polar charts are deprecated! Please
#     170                     switch to "polar" subplots. Sets the direction
#     171                     corresponding to positive angles in legacy
#     172                     polar charts.
#     173                 dragmode
#     174                     Determines the mode of drag interactions.
#     175                     "select" and "lasso" apply only to scatter
#     176                     traces with markers or text. "orbit" and
#     177                     "turntable" apply only to 3D scenes.
#     178                 editrevision
#     179                     Controls persistence of user-driven changes in
#     180                     `editable: true` configuration, other than
#     181                     trace names and axis titles. Defaults to
#     182                     `layout.uirevision`.
#     183                 extendfunnelareacolors
#     184                     If `true`, the funnelarea slice colors (whether
#     185                     given by `funnelareacolorway` or inherited from
#     186                     `colorway`) will be extended to three times its
#     187                     original length by first repeating every color
#     188                     20% lighter then each color 20% darker. This is
#     189                     intended to reduce the likelihood of reusing
#     190                     the same color when you have many slices, but
#     191                     you can set `false` to disable. Colors provided
#     192                     in the trace, using `marker.colors`, are never
#     193                     extended.
#     194                 extendpiecolors
#     195                     If `true`, the pie slice colors (whether given
#     196                     by `piecolorway` or inherited from `colorway`)
#     197                     will be extended to three times its original
#     198                     length by first repeating every color 20%
#     199                     lighter then each color 20% darker. This is
#     200                     intended to reduce the likelihood of reusing
#     201                     the same color when you have many slices, but
#     202                     you can set `false` to disable. Colors provided
#     203                     in the trace, using `marker.colors`, are never
#     204                     extended.
#     205                 extendsunburstcolors
#     206                     If `true`, the sunburst slice colors (whether
#     207                     given by `sunburstcolorway` or inherited from
#     208                     `colorway`) will be extended to three times its
#     209                     original length by first repeating every color
#     210                     20% lighter then each color 20% darker. This is
#     211                     intended to reduce the likelihood of reusing
#     212                     the same color when you have many slices, but
#     213                     you can set `false` to disable. Colors provided
#     214                     in the trace, using `marker.colors`, are never
#     215                     extended.
#     216                 extendtreemapcolors
#     217                     If `true`, the treemap slice colors (whether
# --> 218                     given by `treemapcolorway` or inherited from
#     219                     `colorway`) will be extended to three times its
#     220                     original length by first repeating every color
#     221                     20% lighter then each color 20% darker. This is
#     222                     intended to reduce the likelihood of reusing
#     223                     the same color when you have many slices, but
#     224                     you can set `false` to disable. Colors provided
#     225                     in the trace, using `marker.colors`, are never
#     226                     extended.
#     227                 font
#     228                     Sets the global font. Note that fonts used in
#     229                     traces and other layout components inherit from
#     230                     the global font.
#     231                 funnelareacolorway
#     232                     Sets the default funnelarea slice colors.
#     233                     Defaults to the main `colorway` used for trace
#     234                     colors. If you specify a new list here it can
#     235                     still be extended with lighter and darker
#     236                     colors, see `extendfunnelareacolors`.
#     237                 funnelgap
#     238                     Sets the gap (in plot fraction) between bars of
#     239                     adjacent location coordinates.
#     240                 funnelgroupgap
#     241                     Sets the gap (in plot fraction) between bars of
#     242                     the same location coordinate.
#     243                 funnelmode
#     244                     Determines how bars at the same location
#     245                     coordinate are displayed on the graph. With
#     246                     "stack", the bars are stacked on top of one
#     247                     another With "group", the bars are plotted next
#     248                     to one another centered around the shared
#     249                     location. With "overlay", the bars are plotted
#     250                     over one another, you might need to an
#     251                     "opacity" to see multiple bars.
#     252                 geo
#     253                     :class:`plotly.graph_objects.layout.Geo`
#     254                     instance or dict with compatible properties
#     255                 grid
#     256                     :class:`plotly.graph_objects.layout.Grid`
#     257                     instance or dict with compatible properties
#     258                 height
#     259                     Sets the plot's height (in px).
#     260                 hiddenlabels
#     261                     hiddenlabels is the funnelarea & pie chart
#     262                     analog of visible:'legendonly' but it can
#     263                     contain many labels, and can simultaneously
#     264                     hide slices from several pies/funnelarea charts
#     265                 hiddenlabelssrc
#     266                     Sets the source reference on Chart Studio Cloud
#     267                     for  hiddenlabels .
#     268                 hidesources
#     269                     Determines whether or not a text link citing
#     270                     the data source is placed at the bottom-right
#     271                     cored of the figure. Has only an effect only on
#     272                     graphs that have been generated via forked
#     273                     graphs from the Chart Studio Cloud (at
#     274                     https://chart-studio.plotly.com or on-premise).
#     275                 hoverdistance
#     276                     Sets the default distance (in pixels) to look
#     277                     for data to add hover labels (-1 means no
#     278                     cutoff, 0 means no looking for data). This is
#     279                     only a real distance for hovering on point-like
#     280                     objects, like scatter points. For area-like
#     281                     objects (bars, scatter fills, etc) hovering is
#     282                     on inside the area and off outside, but these
#     283                     objects will not supersede hover on point-like
#     284                     objects in case of conflict.
#     285                 hoverlabel
#     286                     :class:`plotly.graph_objects.layout.Hoverlabel`
#     287                     instance or dict with compatible properties
#     288                 hovermode
#     289                     Determines the mode of hover interactions. If
#     290                     "closest", a single hoverlabel will appear for
#     291                     the "closest" point within the `hoverdistance`.
#     292                     If "x" (or "y"), multiple hoverlabels will
#     293                     appear for multiple points at the "closest" x-
#     294                     (or y-) coordinate within the `hoverdistance`,
#     295                     with the caveat that no more than one
#     296                     hoverlabel will appear per trace. If *x
#     297                     unified* (or *y unified*), a single hoverlabel
#     298                     will appear multiple points at the closest x-
#     299                     (or y-) coordinate within the `hoverdistance`
#     300                     with the caveat that no more than one
#     301                     hoverlabel will appear per trace. In this mode,
#     302                     spikelines are enabled by default perpendicular
#     303                     to the specified axis. If false, hover
#     304                     interactions are disabled. If `clickmode`
#     305                     includes the "select" flag, `hovermode`
#     306                     defaults to "closest". If `clickmode` lacks the
#     307                     "select" flag, it defaults to "x" or "y"
#     308                     (depending on the trace's `orientation` value)
#     309                     for plots based on cartesian coordinates. For
#     310                     anything else the default value is "closest".
#     311                 images
#     312                     A tuple of
#     313                     :class:`plotly.graph_objects.layout.Image`
#     314                     instances or dicts with compatible properties
#     315                 imagedefaults
#     316                     When used in a template (as
#     317                     layout.template.layout.imagedefaults), sets the
#     318                     default property values to use for elements of
#     319                     layout.images
#     320                 legend
#     321                     :class:`plotly.graph_objects.layout.Legend`
#     322                     instance or dict with compatible properties
#     323                 mapbox
#     324                     :class:`plotly.graph_objects.layout.Mapbox`
#     325                     instance or dict with compatible properties
#     326                 margin
#     327                     :class:`plotly.graph_objects.layout.Margin`
#     328                     instance or dict with compatible properties
#     329                 meta
#     330                     Assigns extra meta information that can be used
#     331                     in various `text` attributes. Attributes such
#     332                     as the graph, axis and colorbar `title.text`,
#     333                     annotation `text` `trace.name` in legend items,
#     334                     `rangeselector`, `updatemenus` and `sliders`
#     335                     `label` text all support `meta`. One can access
#     336                     `meta` fields using template strings:
#     337                     `%{meta[i]}` where `i` is the index of the
#     338                     `meta` item in question. `meta` can also be an
#     339                     object for example `{key: value}` which can be
#     340                     accessed %{meta[key]}.
#     341                 metasrc
#     342                     Sets the source reference on Chart Studio Cloud
#     343                     for  meta .
#     344                 modebar
#     345                     :class:`plotly.graph_objects.layout.Modebar`
#     346                     instance or dict with compatible properties
#     347                 newshape
#     348                     :class:`plotly.graph_objects.layout.Newshape`
#     349                     instance or dict with compatible properties
#     350                 orientation
#     351                     Legacy polar charts are deprecated! Please
#     352                     switch to "polar" subplots. Rotates the entire
#     353                     polar by the given angle in legacy polar
#     354                     charts.
#     355                 paper_bgcolor
#     356                     Sets the background color of the paper where
#     357                     the graph is drawn.
#     358                 piecolorway
#     359                     Sets the default pie slice colors. Defaults to
#     360                     the main `colorway` used for trace colors. If
#     361                     you specify a new list here it can still be
#     362                     extended with lighter and darker colors, see
#     363                     `extendpiecolors`.
#     364                 plot_bgcolor
#     365                     Sets the background color of the plotting area
#     366                     in-between x and y axes.
#     367                 polar
#     368                     :class:`plotly.graph_objects.layout.Polar`
#     369                     instance or dict with compatible properties
#     370                 radialaxis
#     371                     :class:`plotly.graph_objects.layout.RadialAxis`
#     372                     instance or dict with compatible properties
#     373                 scene
#     374                     :class:`plotly.graph_objects.layout.Scene`
#     375                     instance or dict with compatible properties
#     376                 selectdirection
#     377                     When `dragmode` is set to "select", this limits
#     378                     the selection of the drag to horizontal,
#     379                     vertical or diagonal. "h" only allows
#     380                     horizontal selection, "v" only vertical, "d"
#     381                     only diagonal and "any" sets no limit.
#     382                 selectionrevision
#     383                     Controls persistence of user-driven changes in
#     384                     selected points from all traces.
#     385                 separators
#     386                     Sets the decimal and thousand separators. For
#     387                     example, *. * puts a '.' before decimals and a
#     388                     space between thousands. In English locales,
#     389                     dflt is ".," but other locales may alter this
#     390                     default.
#     391                 shapes
#     392                     A tuple of
#     393                     :class:`plotly.graph_objects.layout.Shape`
#     394                     instances or dicts with compatible properties
#     395                 shapedefaults
#     396                     When used in a template (as
#     397                     layout.template.layout.shapedefaults), sets the
#     398                     default property values to use for elements of
#     399                     layout.shapes
#     400                 showlegend
#     401                     Determines whether or not a legend is drawn.
#     402                     Default is `true` if there is a trace to show
#     403                     and any of these: a) Two or more traces would
#     404                     by default be shown in the legend. b) One pie
#     405                     trace is shown in the legend. c) One trace is
#     406                     explicitly given with `showlegend: true`.
#     407                 sliders
#     408                     A tuple of
#     409                     :class:`plotly.graph_objects.layout.Slider`
#     410                     instances or dicts with compatible properties
#     411                 sliderdefaults
#     412                     When used in a template (as
#     413                     layout.template.layout.sliderdefaults), sets
#     414                     the default property values to use for elements
#     415                     of layout.sliders
#     416                 spikedistance
#     417                     Sets the default distance (in pixels) to look
#     418                     for data to draw spikelines to (-1 means no
#     419                     cutoff, 0 means no looking for data). As with
#     420                     hoverdistance, distance does not apply to area-
#     421                     like objects. In addition, some objects can be
#     422                     hovered on but will not generate spikelines,
#     423                     such as scatter fills.
#     424                 sunburstcolorway
#     425                     Sets the default sunburst slice colors.
#     426                     Defaults to the main `colorway` used for trace
#     427                     colors. If you specify a new list here it can
#     428                     still be extended with lighter and darker
#     429                     colors, see `extendsunburstcolors`.
#     430                 template
#     431                     Default attributes to be applied to the plot.
#     432                     This should be a dict with format: `{'layout':
#     433                     layoutTemplate, 'data': {trace_type:
#     434                     [traceTemplate, ...], ...}}` where
#     435                     `layoutTemplate` is a dict matching the
#     436                     structure of `figure.layout` and
#     437                     `traceTemplate` is a dict matching the
#     438                     structure of the trace with type `trace_type`
#     439                     (e.g. 'scatter'). Alternatively, this may be
#     440                     specified as an instance of
#     441                     plotly.graph_objs.layout.Template.  Trace
#     442                     templates are applied cyclically to traces of
#     443                     each type. Container arrays (eg `annotations`)
#     444                     have special handling: An object ending in
#     445                     `defaults` (eg `annotationdefaults`) is applied
#     446                     to each array item. But if an item has a
#     447                     `templateitemname` key we look in the template
#     448                     array for an item with matching `name` and
#     449                     apply that instead. If no matching `name` is
#     450                     found we mark the item invisible. Any named
#     451                     template item not referenced is appended to the
#     452                     end of the array, so this can be used to add a
#     453                     watermark annotation or a logo image, for
#     454                     example. To omit one of these items on the
#     455                     plot, make an item with matching
#     456                     `templateitemname` and `visible: false`.
#     457                 ternary
#     458                     :class:`plotly.graph_objects.layout.Ternary`
#     459                     instance or dict with compatible properties
#     460                 title
#     461                     :class:`plotly.graph_objects.layout.Title`
#     462                     instance or dict with compatible properties
#     463                 titlefont
#     464                     Deprecated: Please use layout.title.font
#     465                     instead. Sets the title font. Note that the
#     466                     title's font used to be customized by the now
#     467                     deprecated `titlefont` attribute.
#     468                 transition
#     469                     Sets transition options used during
#     470                     Plotly.react updates.
#     471                 treemapcolorway
#     472                     Sets the default treemap slice colors. Defaults
#     473                     to the main `colorway` used for trace colors.
#     474                     If you specify a new list here it can still be
#     475                     extended with lighter and darker colors, see
#     476                     `extendtreemapcolors`.
#     477                 uirevision
#     478                     Used to allow user interactions with the plot
#     479                     to persist after `Plotly.react` calls that are
#     480                     unaware of these interactions. If `uirevision`
#     481                     is omitted, or if it is given and it changed
#     482                     from the previous `Plotly.react` call, the
#     483                     exact new figure is used. If `uirevision` is
#     484                     truthy and did NOT change, any attribute that
#     485                     has been affected by user interactions and did
#     486                     not receive a different value in the new figure
#     487                     will keep the interaction value.
#     488                     `layout.uirevision` attribute serves as the
#     489                     default for `uirevision` attributes in various
#     490                     sub-containers. For finer control you can set
#     491                     these sub-attributes directly. For example, if
#     492                     your app separately controls the data on the x
#     493                     and y axes you might set
#     494                     `xaxis.uirevision=*time*` and
#     495                     `yaxis.uirevision=*cost*`. Then if only the y
#     496                     data is changed, you can update
#     497                     `yaxis.uirevision=*quantity*` and the y axis
#     498                     range will reset but the x axis range will
#     499                     retain any user-driven zoom.
#     500                 uniformtext
#     501                     :class:`plotly.graph_objects.layout.Uniformtext
#     502                     ` instance or dict with compatible properties
#     503                 updatemenus
#     504                     A tuple of
#     505                     :class:`plotly.graph_objects.layout.Updatemenu`
#     506                     instances or dicts with compatible properties
#     507                 updatemenudefaults
#     508                     When used in a template (as
#     509                     layout.template.layout.updatemenudefaults),
#     510                     sets the default property values to use for
#     511                     elements of layout.updatemenus
#     512                 violingap
#     513                     Sets the gap (in plot fraction) between violins
#     514                     of adjacent location coordinates. Has no effect
#     515                     on traces that have "width" set.
#     516                 violingroupgap
#     517                     Sets the gap (in plot fraction) between violins
#     518                     of the same location coordinate. Has no effect
#     519                     on traces that have "width" set.
#     520                 violinmode
#     521                     Determines how violins at the same location
#     522                     coordinate are displayed on the graph. If
#     523                     "group", the violins are plotted next to one
#     524                     another centered around the shared location. If
#     525                     "overlay", the violins are plotted over one
#     526                     another, you might need to set "opacity" to see
#     527                     them multiple violins. Has no effect on traces
#     528                     that have "width" set.
#     529                 waterfallgap
#     530                     Sets the gap (in plot fraction) between bars of
#     531                     adjacent location coordinates.
#     532                 waterfallgroupgap
#     533                     Sets the gap (in plot fraction) between bars of
#     534                     the same location coordinate.
#     535                 waterfallmode
#     536                     Determines how bars at the same location
#     537                     coordinate are displayed on the graph. With
#     538                     "group", the bars are plotted next to one
#     539                     another centered around the shared location.
#     540                     With "overlay", the bars are plotted over one
#     541                     another, you might need to an "opacity" to see
#     542                     multiple bars.
#     543                 width
#     544                     Sets the plot's width (in px).
#     545                 xaxis
#     546                     :class:`plotly.graph_objects.layout.XAxis`
#     547                     instance or dict with compatible properties
#     548                 yaxis
#     549                     :class:`plotly.graph_objects.layout.YAxis`
#     550                     instance or dict with compatible properties
#     551
#     552     frames
#     553         The 'frames' property is a tuple of instances of
#     554         Frame that may be specified as:
#     555           - A list or tuple of instances of plotly.graph_objs.Frame
#     556           - A list or tuple of dicts of string/value properties that
#     557             will be passed to the Frame constructor
#     558
#     559             Supported dict properties:
#     560
#     561                 baseframe
#     562                     The name of the frame into which this frame's
#     563                     properties are merged before applying. This is
#     564                     used to unify properties and avoid needing to
#     565                     specify the same values for the same properties
#     566                     in multiple frames.
#     567                 data
#     568                     A list of traces this frame modifies. The
#     569                     format is identical to the normal trace
#     570                     definition.
#     571                 group
#     572                     An identifier that specifies the group to which
#     573                     the frame belongs, used by animate to select a
#     574                     subset of frames.
#     575                 layout
#     576                     Layout properties which this frame modifies.
#     577                     The format is identical to the normal layout
#     578                     definition.
#     579                 name
#     580                     A label by which to identify the frame
#     581                 traces
#     582                     A list of trace indices that identify the
#     583                     respective traces in the data attribute
#     584
#     585     skip_invalid: bool
#     586         If True, invalid properties in the figure specification will be
#     587         skipped silently. If False (default) invalid properties in the
#     588         figure specification will result in a ValueError
#     589
#     590     Raises
#     591     ------
#     592     ValueError
#     593         if a property in the specification of data, layout, or frames
#     594         is invalid AND skip_invalid is False
#     595     """
#     596     super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:1415, in update_layout(self, dict1, overwrite, **kwargs)
#    1406 def _select_layout_subplots_by_prefix(
#    1407     self, prefix, selector=None, row=None, col=None, secondary_y=None
#    1408 ):
#    1409     """
#    1410     Helper called by code generated select_* methods
#    1411     """
#    1413     if row is not None or col is not None or secondary_y is not None:
#    1414         # Build mapping from container keys ('xaxis2', 'scene4', etc.)
# -> 1415         # to (row, col, secondary_y) triplets
#    1416         grid_ref = self._validate_get_grid_ref()
#    1417         container_to_row_col = {}
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:5195, in BasePlotlyType.update(self, dict1, overwrite, **kwargs)
#    5193     with self.figure.batch_update():
#    5194         BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 5195         BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5196 else:
#    5197     BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:3963, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3959 val = update_obj[key]
#    3961 if overwrite:
#    3962     # Don't recurse and assign property as-is
# -> 3963     plotly_obj[key] = val
#    3964     continue
#    3966 validator = plotly_obj._get_prop_validator(key)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:5967, in BaseLayoutType.__setitem__(self, prop, value)
#    5964 match = self._subplot_re_match(prop)
#    5965 if match is None:
#    5966     # Set as ordinary property
# -> 5967     super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5968 else:
#    5969     # Set as subplotid property
#    5970     self._set_subplotid_prop(prop, value)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/_plotly_utils/basevalidators.py:2723, in BaseTemplateValidator.validate_coerce(self, v, skip_invalid)
#    2717 if v == {} or isinstance(v, self.data_class) and v.to_plotly_json() == {}:
#    2718     # Replace empty template with {'data': {'scatter': [{}]}} so that we can
#    2719     # tell the difference between an un-initialized template and a template
#    2720     # explicitly set to empty.
#    2721     return self.data_class(data_scatter=[{}])
# -> 2723 return super(BaseTemplateValidator, self).validate_coerce(
#    2724     v, skip_invalid=skip_invalid
#    2725 )
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/_plotly_utils/basevalidators.py:2443, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2439     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2441 elif isinstance(v, self.data_class):
#    2442     # Copy object
# -> 2443     v = self.data_class(v)
#    2444 else:
#    2445     if skip_invalid:
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/graph_objs/layout/_template.py:319, in __init__(self, arg, data, layout, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/_plotly_utils/basevalidators.py:2439, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2436     v = self.data_class()
#    2438 elif isinstance(v, dict):
# -> 2439     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2441 elif isinstance(v, self.data_class):
#    2442     # Copy object
#    2443     v = self.data_class(v)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/graph_objs/layout/template/_data.py:1589, in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, image, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, treemap, violin, volume, waterfall, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:4920, in BasePlotlyType.__setitem__(self, prop, value)
#    4917     self._raise_on_invalid_property_error()(prop)
#    4919 # ### Get validator for this property ###
# -> 4920 validator = self._get_validator(prop)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/basedatatypes.py:4395, in BasePlotlyType._get_validator(self, prop)
#    4392 def _get_validator(self, prop):
#    4393     from .validator_cache import ValidatorCache
# -> 4395     return ValidatorCache.get_validator(self._path_str, prop)
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/plotly/validator_cache.py:48, in ValidatorCache.get_validator(parent_path, prop_name)
#      45 lookup = f"{parent_path}.{lookup_name}" if parent_path else lookup_name
#      47 validator_item = ValidatorCache._json_cache.get(lookup)
# ---> 48 validator_classname = validator_item["superclass"]
#      49 if validator_classname in DERIVED_CLASSES:
#      50     # If the superclass is a derived class, we need to get the base class
#      51     # and pass the derived class name as a parameter
#      52     base_item = ValidatorCache._json_cache.get(
#      53         DERIVED_CLASSES[validator_classname]
#      54     )
#
# TypeError: 'NoneType' object is not subscriptable
