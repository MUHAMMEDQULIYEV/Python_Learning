# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col1'].nunique()
# Out:
# 4

# %%
df['col3'].value_counts()
# Out:
# col3
# abc    1
# def    1
# ghi    1
# xyz    1
# Name: count, dtype: int64

# %%
df['col1'].unique(  )
# Out:
# array([1, 2, 3, 4])

# %%
def times2(nums):
    return nums**2

# %%
df['col1'].agg(times2)
# Out:
# /tmp/ipykernel_47509/2101261003.py:1: FutureWarning: using <function times2 at 0x731ce4236b90> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   df['col1'].agg(times2)
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
df['col1'].apply(times2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
df['col4']=df['col1']/df['col2']

# %%
df
# Out:
#    col1  col2 col3      col4
# 0     1   444  abc  0.002252
# 1     2   555  def  0.003604
# 2     3   666  ghi  0.004505
# 3     4   444  xyz  0.009009

# %%
df.drop('col4',axis=1,inplace=True)

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sort_values('col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi
